# %% [markdown]
# # Doc 2 - Infos sobre tomosíntese e mais informações sobre as imagens do dataset

# %% [markdown]
# ## O que foi feito:
# 1. Analise das  imagens que deram erro no documentação anterior para ver se o problema está nas próprias imagens ou na forma de armazenamento em array (i.e. tem um limite para o armazenamento em uma lista python).
# 2. Checagem da possiblidade da visualização dos outros canais das imagens (e.g. a primeira analisada tem 70 canais).
# 3. Estudo do que é "tomossíntese", que é a forma que as imagens foram obtidas para a base de dados que iremos utilizar.
# 4. Estudo do funcinamento das imagens DICOM
# 5. Análise de como as imagens são armazenadas na base de dados instalada e como é possível relacioná-las com os .csv baixados.
# 6. Pesquisa do que é "actionable" nos labels de diagnóstico.
# 7. Pesquisa do que são os labels LCC, LMLO, RCC, RMLO.

# %% [markdown]
# # 1 - Análise das imagens com erro

# %%
#Imports 
import pydicom as dicom
import matplotlib.pylab as plt
import pandas as pd
import os
import numpy as np
from tabulate import tabulate
import tensorflow_io as tfio
import tensorflow as tf

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00087\01-01-2000-DBT-S04170-MAMMO screening digital bilateral-13031\18035.000000-NA-42700\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00087\01-01-2000-DBT-S04170-MAMMO screening digital bilateral-13031\18037.000000-NA-64410\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00087\01-01-2000-DBT-S04170-MAMMO screening digital bilateral-13031\18038.000000-NA-88999\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00092\01-01-2000-DBT-S01654-MAMMO screening digital bilateral-22406\9250.000000-NA-28048\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00092\01-01-2000-DBT-S01654-MAMMO screening digital bilateral-22406\9251.000000-NA-18575\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00092\01-01-2000-DBT-S01654-MAMMO screening digital bilateral-22406\9253.000000-NA-17798\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00095\01-01-2000-DBT-S05144-Standard Screening - TomoHD-83995\5226.000000-NA-36504\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00095\01-01-2000-DBT-S05144-Standard Screening - TomoHD-83995\5227.000000-NA-04477\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00095\01-01-2000-DBT-S05144-Standard Screening - TomoHD-83995\5228.000000-NA-88226\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00095\01-01-2000-DBT-S05144-Standard Screening - TomoHD-83995\5229.000000-NA-88512\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00118\01-01-2000-DBT-S05326-MAMMO screening digital bilateral-21297\7702.000000-NA-50770\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00118\01-01-2000-DBT-S05326-MAMMO screening digital bilateral-21297\7703.000000-NA-77345\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00118\01-01-2000-DBT-S05326-MAMMO screening digital bilateral-21297\7704.000000-NA-76919\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00118\01-01-2000-DBT-S05386-MAMMO screening digital bilateral-70928\7697.000000-NA-17471\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00118\01-01-2000-DBT-S05386-MAMMO screening digital bilateral-70928\7698.000000-NA-34270\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00118\01-01-2000-DBT-S05386-MAMMO screening digital bilateral-70928\7700.000000-NA-94977\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %% [markdown]
# O erro decorrente na última documentação não ocorre quando abrimos as imagens uma por uma. O problema passado foi provavelente devido ao armazenamento das imagens na lista, a qual deve ter excedido o limite de memória máximo.

# %% [markdown]
# # 2 - Análise dos canais das imagens

# %% [markdown]
# Vamos realizar essa análise na primeira imagem baixada do dataset.

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00004\01-01-2000-DBT-S03764-MAMMO screening digital bilateral-73497\11920.000000-NA-70893\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')

# %%
#Podemos saber o formato da imagem DICOM convertendo-a em um image array:
img_array = ds.pixel_array
img_array.shape
# Out:
# (70, 2457, 1890)

# %%
#Vamos analisar cada uma das imagens:
num_images = img_array.shape[0]
num_cols = 1  
num_rows = (num_images // num_cols) + (num_images % num_cols)  #Para o numero de linhas

plt.figure(figsize=(256, 256))  

for i in range(num_images):
    plt.subplot(num_rows, num_cols, i+1)  
    plt.imshow(img_array[i], cmap='gray')  
    plt.axis('off')  
    plt.title(f"Image {i+1}")  

plt.tight_layout()  
plt.show()

# %% [markdown]
# Comparando as primeiras imagens com as últimas, percebe-se que o nível de detalhe entre elas é diferente. Vale a pena verificar o que cada um desses canais representa.

# %% [markdown]
# # 3 - O que é tomosíntese

# %% [markdown]
# #### Breve resumo
# A tomosíntese é uma mamografia tridimensional que utiliza raios-X para obter imagens seccionais da mama, as quais são então reconstruídas em um volume 3D.
#
# A tomosíntese é realizada movendo o tubo de raios-X em um arco circular e fazendo uma série de exposições de baixa dose, a partir de ângulos diferentes, em poucos segundos. A aquisição de imagens pode ser feita em ambas as visões padrão, meio-lateral-obliqua (MLO) e cranio-caudal (CC), bem como em visões adicionais. As imagens de projeção obtidas são então reconstruídas em imagens com espessura de 1 mm para revisão. O número total de imagens reconstruídas depende da espessura da mama comprimida. Em uma mama comprimida de 60 mm, por exemplo, haverá 60 imagens para o médico revisar.
#
# Posteriormente, todas as imagens são usadas para reconstruir uma imagem sintetizada 2D, na qual todos os detalhes registrados nas imagens finas são representados, sem sobreposição, como ocorre na mamografia 2D clássica.
#
# O modo combo (2D+3D) é frequentemente utilizado na prática clínica para aquisição de imagens. Usando o modo combo, no mesmo exame, são realizadas mamografia digital 2D e tomosíntese, com a vantagem para o radiologista de comparar as informações fornecidas pelas duas modalidades e aumentar a precisão da interpretação, mas também com a desvantagem para o paciente devido ao risco do aumento da dose de irradiação. A substituição da mamografia 2D pelas imagens sintetizadas 2D da tomosíntese pode reduzir em quase 50% a dose de irradiação, e este é o tema de muitos estudos realizados atualmente.

# %% [markdown]
# Fonte - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7664734/#:~:text=Tomosynthesis%20is%20a%20three%2Ddimensional,angles%2C%20in%20a%20few%20seconds.

# %% [markdown]
# ## Mamografia digital por tomosíntese
#
# A mamografia digital da mama por meio de tomosíntese (DBT) é uma tecnologia em desenvolvimento para melhorar a detecção e caracterização de lesões na mama, especialmente em mulheres com mamas não gordurosas.  <b> Nesta técnica, múltiplas imagens de projeção são reconstruídas permitindo a revisão visual de seções finas da mama, oferecendo o potencial para revelar cânceres ocultos por tecido normal localizado acima e abaixo da lesão. </b> A DBT envolve a aquisição de múltiplas exposições de projeção por um detector digital a partir de uma fonte de raios-X mamográfica que se move sobre um ângulo de arco limitado. Esses conjuntos de dados de imagem de projeção são reconstruídos usando algoritmos específicos. O "leitor clínico" é apresentado com uma série de imagens (fatias) através de toda a mama, que são lidas em uma estação de trabalho semelhante à revisão de um estudo de TC ou RM. Como cada fatia reconstruída pode ter apenas 0,5 mm de espessura, massas e margens de massa que de outra forma podem estar sobrepostas com estruturas fora do plano devem ser mais visíveis na fatia reconstruída. Isso deve permitir a visualização (detecção) e melhor caracterização de lesões não calcificadas em particular.

# %% [markdown]
# ## Técnica utilizada
#
# O surgimento da mamografia digital e dos algoritmos de reconstrução por computador permitiu o desenvolvimento de tecnologias derivadas, incluindo a tomosíntese. Na mamografia digital convencional, uma mama comprimida é exposta à radiação ionizante. A energia que passa pela mama é transformada em um sinal elétrico por um detector que produz a imagem clínica. O tubo de raios-X é estacionário, a mama é estacionária e o detector é estacionário. A imagem produzida em uma única projeção, como uma vista CC ou MLO, é uma representação bidimensional do espaço tridimensional. Cada pixel é, portanto, uma média das informações obtidas através da espessura total da mama. Uma representação tridimensional da mama seria vantajosa, semelhante às representações tridimensionais permitidas pela TC, RM ou ultrassonografia.
#
# <b> Na tomosíntese digital da mama, o tubo de raios-X é movido através de um ângulo de arco limitado enquanto a mama é comprimida e uma série de exposições são obtidas </b>. Essas exposições individuais representam apenas uma fração da dose total usada durante a mamografia digital convencional. A dose total utilizada deve estar dentro dos limites da FDA e espera-se que seja próxima ou ligeiramente acima da dose mamográfica de rotina, se a DBT for clinicamente aprovada. <b> Se houver um arco de movimento de 45 graus e uma exposição for feita a cada 3 graus, haverá 15 exposições individuais </b>. Esses conjuntos de dados brutos de "projeção" requerem reconstrução usando algoritmos semelhantes aos usados em outros conjuntos de imagens tridimensionais. Os conjuntos de dados de projeção geralmente não são interpretados pelos radiologistas, mas sim a interpretação é baseada apenas nas imagens "tomosíntese" reconstruídas. Tipicamente, os conjuntos de dados de projeção são reconstruídos em fatias muito finas (por exemplo, 1 mm) para revisão pelo radiologista.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Técnica de imagem
#
# Vários fabricantes aplicaram diferentes métodos para desenvolver e realizar a tomosíntese. Provavelmente, existem vantagens e desvantagens de cada técnica. No entanto, essas diferenças podem produzir resultados clínicos diferentes, tornando as comparações clínicas entre os fabricantes difíceis. As restrições de engenharia incluem a dose total de radiação, tempo de imagem, movimento do paciente, desempenho do detector, movimento do detector e capacidade de imaginar toda a mama. Também é necessário fornecer capacidade futura de biópsia para aquelas lesões detectadas apenas pela tomosíntese.
#
# <b> Os fabricantes variam o arco de movimento (tipicamente 11-60°), o número de exposições individuais (tipicamente 9-25) </b>, o uso de exposição contínua ou pulsada, estabilidade ou movimento do detector, parâmetros de exposição, dose total, tamanho efetivo dos pixels, fonte de raios-X/filtro, pixels únicos ou agrupados e posição do paciente. Essas decisões teóricas e de engenharia podem levar a resultados clínicos diferentes e recomendações de leitura diferentes para os diferentes fabricantes. De particular importância é a avaliação de microcalcificações e se se tenta representar com precisão microcalcificações por DBT. Devido ao ângulo limitado de varredura, as imagens são apenas "quase" 3D. O plano x-y perpendicular ao feixe de raios-X tem a maior resolução. Há menos resolução no plano paralelo ou eixo z. Pode-se reconstruir o conjunto de dados para o radiologista ler exibindo diferentes espessuras. <b> Por exemplo, se uma mama comprimida de 60 cm for reconstruída com espessura de 1 mm, haverá 60 fatias para o médico revisar. Se as imagens forem reconstruídas com espessuras de 0,5 mm, haverá 120 imagens a serem revisadas. Se as imagens forem reconstruídas com "lâminas" de 10 mm de espessura usando projeção de intensidade máxima (MIP), haverá 6 imagens a serem revisadas </b>.
#
# Fonte - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3118307/#:~:text=In%20digital%20breast%20tomosynthesis%2C%20the,used%20during%20conventional%20digital%20mammography.

# %% [markdown]
# <b> A partir do que é apresentado acima, pode-se pensar que cada um dos canais das imagens DICOM da base de dados pode possivelmente representar uma dessas imagens de projeção reconstruídas. </b>
#
# <b> Na verdade o que temos então é que, cada arquivo .dcm contém diversas imagens contidas nele, em que cada canal representa uma imagem. </b>

# %% [markdown]
# # 4 - O que são imagens DICOM (Digital Imaging and Communications in Medicine)
#
# ## Introdução
#
# Todas as modalidades na prática radiológica se tornaram digitais e, portanto, lidam com imagens DICOM. Arquivos de imagem que estão em conformidade com a parte 10 do padrão DICOM geralmente são chamados de "arquivos no formato DICOM" ou simplesmente "arquivos DICOM" e são representados como ".dcm". <b> O DICOM difere de outros formatos de imagem por agrupar informações em conjuntos de dados. Um arquivo DICOM consiste em um cabeçalho e conjuntos de dados de imagem compactados em um único arquivo. As informações dentro do cabeçalho são organizadas como uma série constante e padronizada de tags. Ao extrair dados dessas tags, é possível acessar informações importantes sobre as características demográficas do paciente, parâmetros do estudo, etc </b>. <u> No interesse da confidencialidade do paciente, todas as informações que podem ser usadas para identificar o paciente devem ser removidas antes que as imagens DICOM sejam transmitidas pela rede para fins educacionais ou outros </u>.

# %% [markdown]
# ## O que são as "partes" da imagem DICOM
#
# O DICOM difere de outros formatos de imagem por agrupar informações em conjuntos de dados. Um arquivo DICOM consiste em um cabeçalho e conjuntos de dados de imagem, todos compactados em um único arquivo.
#
# Os primeiros pacotes de informação em um arquivo de imagem DICOM constituem o "cabeçalho". Ele armazena informações demográficas sobre o paciente, parâmetros de aquisição para o estudo de imagem, dimensões da imagem, tamanho da matriz, espaço de cores e uma série de informações não relacionadas à intensidade necessárias para que o computador exiba corretamente a imagem (<b>Essa parte muito provavelmente foi removida das imagens da base de dados, visto que é uma base de dados pública </b>). O cabeçalho é seguido por um único atributo (7FE0) que contém todos os dados de intensidade de pixel da imagem. Esses dados são armazenados como uma longa série de 0s e 1s, que podem ser reconstruídos como a imagem usando as informações do cabeçalho. Este atributo pode conter informações sobre uma única imagem, múltiplos quadros de um estudo ou um loop de cine, dependendo da modalidade que gerou a imagem.
#
# As informações dos dados do cabeçalho são codificadas dentro do arquivo DICOM de forma que não possam ser separadas acidentalmente dos dados da imagem. Se o cabeçalho for separado dos dados da imagem, o computador não saberá qual estudo de imagem foi realizado ou a quem pertence, e não será capaz de exibir corretamente a imagem, levando a uma situação potencialmente médico-legal.
#
# ![image.png](attachment:image.png)
#
# Fonte - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3354356/#:~:text=A%20DICOM%20file%20consists%20of,demographics%2C%20study%20parameters%2C%20etc

# %% [markdown]
# # 5 - Armazenamento das imagens

# %% [markdown]
# ## Teste do codigo do repositório

# %% [markdown]
# Precisei instalar uma versao especifica do pandas para esse codigo funcionar - 1.1.4

# %%
from typing import AnyStr, BinaryIO, Dict, List, NamedTuple, Optional, Union

import matplotlib
import numpy as np
import pandas as pd
import pydicom as dicom
from skimage.exposure import rescale_intensity


def dcmread_image(
    fp: Union[str, "os.PathLike[AnyStr]", BinaryIO],
    view: str,
    index: Optional[np.uint] = None,
) -> np.ndarray:
    """Read pixel array from DBT DICOM file"""
    ds = dicom.dcmread(fp)
    ds.decompress(handler_name="pylibjpeg")
    pixel_array = ds.pixel_array
    view_laterality = view[0].upper()
    image_laterality = _get_image_laterality(pixel_array[index or 0])
    if index is not None:
        pixel_array = pixel_array[index]
    if not image_laterality == view_laterality:
        pixel_array = np.flip(pixel_array, axis=(-1, -2))
    window_center = _get_window_center(ds)
    window_width = _get_window_width(ds)
    low = (2 * window_center - window_width) / 2
    high = (2 * window_center + window_width) / 2
    pixel_array = rescale_intensity(
        pixel_array, in_range=(low, high), out_range="dtype"
    )
    return pixel_array


def read_boxes(
    boxes_fp: pd._typing.FilePathOrBuffer, filepaths_fp: pd._typing.FilePathOrBuffer
) -> pd.DataFrame:
    """Read pandas DataFrame with bounding boxes joined with file paths"""
    df_boxes = pd.read_csv(boxes_fp)
    df_filepaths = pd.read_csv(filepaths_fp)
    primary_key = ("PatientID", "StudyUID", "View")
    if not all([key in df_boxes.columns for key in primary_key]):
        raise AssertionError(
            f"Not all primary key columns {primary_key} are present in bounding boxes columns {df_boxes.columns}"
        )
    if not all([key in df_boxes.columns for key in primary_key]):
        raise AssertionError(
            f"Not all primary key columns {primary_key} are present in file paths columns {df_filepaths.columns}"
        )
    return pd.merge(df_boxes, df_filepaths, on=primary_key)


def draw_box(
    image: np.ndarray,
    x: int,
    y: int,
    width: int,
    height: int,
    color: Optional[Union[int, tuple]] = None,
    lw=4,
):
    """Draw bounding box on the image"""
    x = min(max(x, 0), image.shape[1] - 1)
    y = min(max(y, 0), image.shape[0] - 1)
    if color is None:
        color = np.max(image)
    if len(image.shape) > 2 and not hasattr(color, "__len__"):
        color = (color,) + (0,) * (image.shape[-1] - 1)
    image[y : y + lw, x : x + width] = color
    image[y + height - lw : y + height, x : x + width] = color
    image[y : y + height, x : x + lw] = color
    image[y : y + height, x + width - lw : x + width] = color
    return image


def evaluate(
    labels_fp: pd._typing.FilePathOrBuffer,
    boxes_fp: pd._typing.FilePathOrBuffer,
    predictions_fp: pd._typing.FilePathOrBuffer,
) -> Dict[str, float]:
    """Evaluate predictions"""
    df_labels = pd.read_csv(labels_fp)
    df_boxes = pd.read_csv(boxes_fp, dtype={"VolumeSlices": float})
    df_pred = pd.read_csv(predictions_fp, dtype={"Score": float})

    df_labels = df_labels.reset_index().set_index(["StudyUID", "View"]).sort_index()
    df_boxes = df_boxes.reset_index().set_index(["StudyUID", "View"]).sort_index()
    df_pred = df_pred.reset_index().set_index(["StudyUID", "View"]).sort_index()

    df_pred["TP"] = 0
    df_pred["GTID"] = -1

    thresholds = [df_pred["Score"].max() + 1.0]

    # find true positive predictions and assign detected ground truth box ID
    for box_pred in df_pred.itertuples():
        if box_pred.Index not in df_boxes.index:
            continue

        df_boxes_view = df_boxes.loc[[box_pred.Index]]
        view_slice_offset = df_boxes.loc[[box_pred.Index], "VolumeSlices"].iloc[0] / 4
        tp_boxes = [
            b
            for b in df_boxes_view.itertuples()
            if _is_tp(box_pred, b, slice_offset=view_slice_offset)
        ]
        if len(tp_boxes) > 1:
            # find the nearest GT box
            tp_distances = [_distance(box_pred, b) for b in tp_boxes]
            tp_boxes = [tp_boxes[np.argmin(tp_distances)]]
        if len(tp_boxes) > 0:
            tp_i = tp_boxes[0].index
            df_pred.loc[df_pred["index"] == box_pred.index, ("TP", "GTID")] = (1, tp_i)
            thresholds.append(box_pred.Score)

    thresholds.append(df_pred["Score"].min() - 1.0)

    # compute sensitivity at 2 FPs/volume on all cases
    evaluation_fps_all = (2.0,)
    tpr_all = _froc(
        df_pred=df_pred,
        thresholds=thresholds,
        n_volumes=len(df_labels),
        n_boxes=len(df_boxes),
        evaluation_fps=evaluation_fps_all,
    )
    result = {f"sensitivity_at_2_fps_all": tpr_all[0]}

    # compute mean sensitivity at 1, 2, 3, 4 FPs/volume on positive cases
    df_pred = df_pred[df_pred.index.isin(df_boxes.index)]
    df_labels = df_labels[df_labels.index.isin(df_boxes.index)]
    evaluation_fps_positive = (1.0, 2.0, 3.0, 4.0)
    tpr_positive = _froc(
        df_pred=df_pred,
        thresholds=thresholds,
        n_volumes=len(df_labels),
        n_boxes=len(df_boxes),
        evaluation_fps=evaluation_fps_positive,
    )

    result.update(
        dict(
            (f"sensitivity_at_{int(x)}_fps_positive", y)
            for x, y in zip(evaluation_fps_positive, tpr_positive)
        )
    )
    result.update({"mean_sensitivity_positive": np.mean(tpr_positive)})

    return result


def _froc(
    df_pred: pd.DataFrame,
    thresholds: List[float],
    n_volumes: int,
    n_boxes: int,
    evaluation_fps: tuple,
) -> List[float]:
    tpr = []
    fps = []
    for th in sorted(thresholds, reverse=True):
        df_th = df_pred.loc[df_pred["Score"] >= th]
        df_th_unique_tp = df_th.reset_index().drop_duplicates(
            subset=["StudyUID", "View", "TP", "GTID"]
        )
        n_tps_th = float(sum(df_th_unique_tp["TP"]))
        tpr_th = n_tps_th / n_boxes
        n_fps_th = float(len(df_th[df_th["TP"] == 0]))
        fps_th = n_fps_th / n_volumes
        tpr.append(tpr_th)
        fps.append(fps_th)
        if fps_th > max(evaluation_fps):
            break
    return [np.interp(x, fps, tpr) for x in evaluation_fps]


def _is_tp(
    box_pred: NamedTuple, box_true: NamedTuple, slice_offset: int, min_dist: int = 100
) -> bool:
    pred_y = box_pred.Y + box_pred.Height / 2
    pred_x = box_pred.X + box_pred.Width / 2
    pred_z = box_pred.Z + box_pred.Depth / 2
    true_y = box_true.Y + box_true.Height / 2
    true_x = box_true.X + box_true.Width / 2
    true_z = box_true.Slice
    # 2D distance between true and predicted center points
    dist = np.linalg.norm((pred_x - true_x, pred_y - true_y))
    # compute radius based on true box size
    dist_threshold = np.sqrt(box_true.Width ** 2 + box_true.Height ** 2) / 2.0
    dist_threshold = max(dist_threshold, min_dist)
    slice_diff = np.abs(pred_z - true_z)
    # TP if predicted center within radius and slice within slice offset
    return dist <= dist_threshold and slice_diff <= slice_offset


def _distance(box_pred: NamedTuple, box_true: NamedTuple) -> float:
    pred_y = box_pred.Y + box_pred.Height / 2
    pred_x = box_pred.X + box_pred.Width / 2
    pred_z = box_pred.Z + box_pred.Depth / 2
    true_y = box_true.Y + box_true.Height / 2
    true_x = box_true.X + box_true.Width / 2
    true_z = box_true.Slice
    return np.linalg.norm((pred_x - true_x, pred_y - true_y, pred_z - true_z))


def _get_dicom_laterality(ds: dicom.dataset.FileDataset) -> str:
    """Unreliable - DICOM laterality is incorrect for some cases"""
    return ds[0x5200, 0x9229][0][0x0020, 0x9071][0][0x0020, 0x9072].value


def _get_image_laterality(pixel_array: np.ndarray) -> str:
    left_edge = np.sum(pixel_array[:, 0])  # sum of left edge pixels
    right_edge = np.sum(pixel_array[:, -1])  # sum of right edge pixels
    return "R" if left_edge < right_edge else "L"


def _get_window_center(ds: dicom.dataset.FileDataset) -> np.float32:
    return np.float32(ds[0x5200, 0x9229][0][0x0028, 0x9132][0][0x0028, 0x1050].value)


def _get_window_width(ds: dicom.dataset.FileDataset) -> np.float32:
    return np.float32(ds[0x5200, 0x9229][0][0x0028, 0x9132][0][0x0028, 0x1051].value)

# %% [markdown]
# Inicialmente surgiu um problema para usar o código do github porque, por algum motivo, as pastas dos arquivos baixados tem um nome diferente do que está no .csv para encontrar cada uma das imagens (possuem um "-NA" a mais). Por esse motivo fiz esse código para renomear cada um dos folders que contém as imagens para tirar esse caracteres adicionais.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
root_dir = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT'

#Acha o folder
for foldername, subfolders, filenames in os.walk(root_dir):
    for subfolder in subfolders:
        #Checa se tem o "-NA", que era o que tinha de diferente
        if '-NA' in subfolder:
            #Tira o "-NA" e deixa vazio colcando ''
            new_subfolder = subfolder.replace('-NA', '')
            old_path = os.path.join(foldername, subfolder)
            new_path = os.path.join(foldername, new_subfolder)
            #Faz o rename
            os.rename(old_path, new_path)
            print(f'Renamed folder: {old_path} -> {new_path}')
# Out:
# Renamed folder: D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00004\01-01-2000-DBT-S03764-MAMMO screening digital bilateral-73497\11920.000000-NA-70893 -> D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00004\01-01-2000-DBT-S03764-MAMMO screening digital bilateral-73497\11920.000000-70893
# Renamed folder: D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00004\01-01-2000-DBT-S03764-MAMMO screening digital bilateral-73497\11922.000000-NA-44222 -> D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00004\01-01-2000-DBT-S03764-MAMMO screening digital bilateral-73497\11922.000000-44222
# ...

# %% [markdown]
# Agora está igual ao .csv
# ![image.png](attachment:image.png)

# %% [markdown]
# No código abaixo estamos olhando a 1a imagem que eu baixei do dataset, do paciente DBT-P00004, que corresponde à 668a linha.

# %%
df.iloc[668]
# Out:
# PatientID                                                  DBT-P00004
# StudyUID                                                   DBT-S03764
# View                                                             rmlo
# descriptive_path    Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2...
# classic_path        Breast-Cancer-Screening-DBT/DBT-P00004/1.2.826...
# Name: 668, dtype: object

# %%
df.iloc[668]["descriptive_path"]
# Out:
# 'Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2000-DBT-S03764-MAMMO screening digital bilateral-73497/11920.000000-70893/1-1.dcm'

# %%
df[df["PatientID"] == "DBT-P00004"]
# Out:
#       PatientID    StudyUID  View  \
# 665  DBT-P00004  DBT-S03764   lcc
# 666  DBT-P00004  DBT-S03764  lmlo
# 667  DBT-P00004  DBT-S03764   rcc
# 668  DBT-P00004  DBT-S03764  rmlo
#
#                                       descriptive_path  \
# 665  Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2...
# 666  Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2...
# 667  Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2...
# 668  Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2...
#
#                                           classic_path
# 665  Breast-Cancer-Screening-DBT/DBT-P00004/1.2.826...
# 666  Breast-Cancer-Screening-DBT/DBT-P00004/1.2.826...
# 667  Breast-Cancer-Screening-DBT/DBT-P00004/1.2.826...
# 668  Breast-Cancer-Screening-DBT/DBT-P00004/1.2.826...

# %%
# %%time
df = pd.read_csv(r"D:\Coisinhas\Coisas_UNB\TCC\Imagens\BCS-DBT-file-paths-test-v2.csv") #Arquivo das paths para pegar as imagens
view_series = df.iloc[668]
view = view_series["View"]
image_path = os.path.join(r'D:/Coisinhas/Coisas_UNB/TCC/Imagens/manifest-1708019969874/', view_series["descriptive_path"])
image = dcmread_image(fp=image_path, view=view)
# Out:
# C:\Users\breno\anaconda3\lib\site-packages\openjpeg\utils.py:313: UserWarning: The (0028,0101) Bits Stored value '10' in the dataset does not match the component precision value '16' found in the JPEG 2000 data. It's recommended that you change the Bits Stored value to produce the correct output
#   warnings.warn(
# CPU times: total: 12 s
# Wall time: 53.3 s

# %%
plt.imshow(image[0], cmap=plt.cm.gray)

# %%
image_path = r'D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\Breast-Cancer-Screening-DBT\DBT-P00004\01-01-2000-DBT-S03764-MAMMO screening digital bilateral-73497\11920.000000-70893\1-1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array[0], cmap = 'gray')
# Out:
# C:\Users\breno\anaconda3\lib\site-packages\pydicom\pixel_data_handlers\pillow_handler.py:238: UserWarning: The (0028,0101) 'Bits Stored' value (10-bit) doesn't match the JPEG 2000 data (16-bit). It's recommended that you change the 'Bits Stored' value
#   warnings.warn(

# %% [markdown]
# Podemos ver uma diferença bem grande das informações que cada uma das imagens passa.

# %% [markdown]
# Uma ideia do que podemos fazer - temos o todos os patient IDs no dataset das filepaths. Podemos relacionar essas paths com as imagens e também com os diagnósticos a partir dos valores no .csv deles, já que eles também tem uma coluna de PatientID.

# %%
df[df["PatientID"] == "DBT-P00004"]
# Out:
#       PatientID    StudyUID  View  \
# 665  DBT-P00004  DBT-S03764   lcc
# 666  DBT-P00004  DBT-S03764  lmlo
# 667  DBT-P00004  DBT-S03764   rcc
# 668  DBT-P00004  DBT-S03764  rmlo
#
#                                       descriptive_path  \
# 665  Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2...
# 666  Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2...
# 667  Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2...
# 668  Breast-Cancer-Screening-DBT/DBT-P00004/01-01-2...
#
#                                           classic_path
# 665  Breast-Cancer-Screening-DBT/DBT-P00004/1.2.826...
# 666  Breast-Cancer-Screening-DBT/DBT-P00004/1.2.826...
# 667  Breast-Cancer-Screening-DBT/DBT-P00004/1.2.826...
# 668  Breast-Cancer-Screening-DBT/DBT-P00004/1.2.826...

# %%
df2 = pd.read_csv(r"D:\Coisinhas\Coisas_UNB\TCC\Imagens\manifest-1708019969874\BCS-DBT-labels-test-PHASE-2.csv") #Arquivo dos diagnosticos
df2[df2['PatientID'] == "DBT-P00004"]
# Out:
#       PatientID    StudyUID  View  Normal  Actionable  Benign  Cancer
# 441  DBT-P00004  DBT-S03764   lcc       1           0       0       0
# 442  DBT-P00004  DBT-S03764  lmlo       1           0       0       0
# 443  DBT-P00004  DBT-S03764   rcc       1           0       0       0
# 444  DBT-P00004  DBT-S03764  rmlo       1           0       0       0

# %% [markdown]
# Uma outra coisa que é possível seria renomer cada uma das imagens com seus PatientIDs, o que talvez facilitaria a obtenção dos labels para a rede.

# %% [markdown]
# # 6 - O que significa "actionable" na base de dados
#
# De acordo com o sumário na base de dados (https://www.cancerimagingarchive.net/collection/breast-cancer-screening-dbt/), temos que cada imagem é classificada como <b> normal, actionable, biopsy-proven benign, and biopsy-proven cancer cases </b>.
#
# Normal,benigno e maligno são casos óbvios do que representam, já o "actionable" é um termo que desconheço.
#
# Mutações "actionable" (acionáveis?) se referem a alterações no DNA que, se detectadas, espera-se que responderiam aos tratamentos dados aos paciente. Entre essas mutações, as mais clinicamente impactantes podem ser direcionadas com medicamentos ou terapias específicas, conhecidas como mutações alvo.
#
# Fonte - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10252025/#:~:text=Actionable%20mutations%20refer%20to%20DNA,therapies%2C%20known%20as%20targetable%20mutations.
#
# Possível fonte a set analisada - https://pubmed.ncbi.nlm.nih.gov/37938385/

# %% [markdown]
# # 7 - LCC, LMLO, RCC, RMLO
#
# Left mediolateral oblique view (LMLO), right mediolateral oblique view (RMLO), left craniocaudal view (LCC), and right craniocaudal view (RCC).
#
# Fonte - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3043824/
